# %%
# trigger autocomplete
# %config IPCompleter.greedy=True

# %%
import pandas as pd
from time import time
from sqlalchemy import create_engine

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
df = pd.read_csv("yellow_tripdata_2021-01.csv", nrows=100)
df
# df.head(100)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47                1
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03                2
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25                2
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44                1
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41                3
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
df_schema = pd.io.sql.get_schema(df, "yellow_tripdata_schema")
print(df_schema)
# Out:
# CREATE TABLE "yellow_tripdata_schema" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
# create sqlalchemy engine for the ny_taxi postgres container
conn_nytaxi = "postgresql://root:root12345@localhost:5432/ny_taxi"
engine = create_engine(conn_nytaxi)

# %%
# pickup datetimes are currently in TEXT, these needs to be converted accordingly
df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])
df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])

df_schema = pd.io.sql.get_schema(df, "yellow_tripdata_schema", con=engine)
print(df_schema)
# Out:
# CREATE TABLE yellow_tripdata_schema (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
# implement dataframe iterator s=to split large datasets to chunks
df_iter = pd.read_csv("yellow_tripdata_2021-01.csv", iterator=True, chunksize=100000)

# %%
# # insert data by chunks
# while True:
#     t_start = time()
    
#     df_curr_chunk = next(df_iter)

#     df_curr_chunk["tpep_pickup_datetime"] = pd.to_datetime(df_curr_chunk["tpep_pickup_datetime"])
#     df_curr_chunk["tpep_dropoff_datetime"] = pd.to_datetime(df_curr_chunk["tpep_dropoff_datetime"])

#     # finally append data
#     df_curr_chunk.to_sql(name="yellow_taxi_data", con=engine, if_exists="append")

#     t_end = time()
#     print(f"chunk inserted...duration: {t_end - t_start:.4f} seconds")

# %%
# flag for iter 1
is_first_iter = True

for df_chunk in df_iter:

    t_start = time()
    
    # pickup datetimes are currently in TEXT, these needs to be converted accordingly
    df_chunk["tpep_pickup_datetime"] = pd.to_datetime(df_chunk["tpep_pickup_datetime"])
    df_chunk["tpep_dropoff_datetime"] = pd.to_datetime(df_chunk["tpep_dropoff_datetime"])

    # create table schema in postgres (table without data)
    if is_first_iter:
        df_chunk.head(0).to_sql(name="yellow_taxi_data", con=engine, if_exists="replace")
    
    df_chunk.to_sql(name="yellow_taxi_data", con=engine, if_exists="append")

    t_end = time()
    print(f"chunk inserted...duration: {t_end - t_start:.4f} seconds")

    is_first_iter = False

print(f"Pipeline completed...")
# Out:
# chunk inserted...duration: 35.7473 seconds
# chunk inserted...duration: 32.6862 seconds
# chunk inserted...duration: 32.2389 seconds
# chunk inserted...duration: 30.3330 seconds
# chunk inserted...duration: 30.9564 seconds
# chunk inserted...duration: 32.1646 seconds
# chunk inserted...duration: 32.0116 seconds
# chunk inserted...duration: 32.2823 seconds
# chunk inserted...duration: 31.2327 seconds
# chunk inserted...duration: 32.6600 seconds
# chunk inserted...duration: 32.2063 seconds
# chunk inserted...duration: 32.3510 seconds
# /tmp/ipykernel_21571/769683131.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   for df_chunk in df_iter:
# chunk inserted...duration: 32.1168 seconds
# chunk inserted...duration: 20.2497 seconds
